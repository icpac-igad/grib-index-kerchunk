# %%
import datetime
import copy
import xarray as xr
import numpy as np
import pandas as pd
import fsspec
import kerchunk
from kerchunk.grib2 import scan_grib, grib_tree
import gcsfs
import datatree
import pickle


# This could be generalized to any gridded FMRC da/taset but right now it works with NOAA's Grib2 files
import dynamic_zarr_store

axes = [
  pd.Index(
    [
      pd.timedelta_range(start="0 hours", end="6 hours", freq="6h", closed="right", name="6 hour"),
    ],
    name="step"
  ),
  pd.date_range("2023-09-01T06:00", "2023-10T00:00", freq="360min", name="valid_time")
]
axes
# Out:
# [Index([[0 days 06:00:00]], dtype='object', name='step'),
#  DatetimeIndex(['2023-09-01 06:00:00', '2023-09-01 12:00:00',
#                 '2023-09-01 18:00:00', '2023-09-02 00:00:00',
#                 '2023-09-02 06:00:00', '2023-09-02 12:00:00',
#                 '2023-09-02 18:00:00', '2023-09-03 00:00:00',
#                 '2023-09-03 06:00:00', '2023-09-03 12:00:00',
#                 ...
#                 '2023-09-28 18:00:00', '2023-09-29 00:00:00',
#                 '2023-09-29 06:00:00', '2023-09-29 12:00:00',
#                 '2023-09-29 18:00:00', '2023-09-30 00:00:00',
#                 '2023-09-30 06:00:00', '2023-09-30 12:00:00',
#                 '2023-09-30 18:00:00', '2023-10-01 00:00:00'],
#                dtype='datetime64[ns]', name='valid_time', length=120, freq='360min')]

# %%
mapping = dynamic_zarr_store.build_idx_grib_mapping(
    fs=fsspec.filesystem(""),
    basename="/home/sparrow/Documents/sewaa_data/gfs_demo_data/gfs.t00z.pgrb2.0p25.f006",
)
mapping
# Out:
# Dropping unknown variable in msg# 0. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 0. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 0. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 0. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# The idx attribute mapping for /home/sparrow/Documents/sewaa_data/gfs_demo_data/gfs.t00z.pgrb2.0p25.f006 is not unique for 4 variables: ['tp', 'tp', 'acpcp', 'acpcp']
# The grib hierarchy in /home/sparrow/Documents/sewaa_data/gfs_demo_data/gfs.t00z.pgrb2.0p25.f006 is not unique for 30 variables: ['st', 'soilw', 'soill', 'st', 'soilw', 'soill', 'st', 'soilw', 'soill', 'st', 'soilw', 'soill', nan, nan, nan, 'tp', 'tp', 'acpcp', 'acpcp', 'cape', 'cin', nan, 'r', 'r', 'r', 'r', 'cape', 'cin', 'cape', 'cin']
#      offset_idx          date  \
# idx
# 1             0  d=2023092800
# 2        984804  d=2023092800
# 3       1070431  d=2023092800
# 4       1314876  d=2023092800
# 5       1551504  d=2023092800
# ..          ...           ...
# 739   535590536  d=2023092800
# 740   536236809  d=2023092800
# 741   536887172  d=2023092800
# 742   538061812  d=2023092800
# 743   539196945  d=2023092800
#
#                                                  attrs  length_idx  \
# idx
# 1                  PRMSL:mean sea level:6 hour fcst:\n      984804
# 2                  CLWMR:1 hybrid level:6 hour fcst:\n       85627
# 3                   ICMR:1 hybrid level:6 hour fcst:\n      244445
# 4                   RWMR:1 hybrid level:6 hour fcst:\n      236628
# 5                   SNMR:1 hybrid level:6 hour fcst:\n       78043
# ..                                                 ...         ...
# 739  VGRD:PV=-2e-06 (Km^2/kg/s) surface:6 hour fcst:\n      646273
# 740   TMP:PV=-2e-06 (Km^2/kg/s) surface:6 hour fcst:\n      650363
# 741   HGT:PV=-2e-06 (Km^2/kg/s) surface:6 hour fcst:\n     1174640
# 742  PRES:PV=-2e-06 (Km^2/kg/s) surface:6 hour fcst:\n     1135133
# 743  VWSH:PV=-2e-06 (Km^2/kg/s) surface:6 hour fcst:\n      499482
#
#                                                idx_uri  \
# idx
# 1    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 2    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 3    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 4    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 5    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# ..                                                 ...
# 739  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 740  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 741  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 742  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 743  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
#
#                                               grib_uri  \
# idx
# 1    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 2    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 3    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 4    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 5    /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# ..                                                 ...
# 739  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 740  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 741  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 742  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
# 743  /home/sparrow/Documents/sewaa_data/gfs_demo_da...
#
#                     indexed_at grib_crc32 grib_updated_at idx_crc32  ...  \
# idx                                                                  ...
# 1   2024-06-24 15:10:07.208587       None            None      None  ...
# 2   2024-06-24 15:10:07.208587       None            None      None  ...
# 3   2024-06-24 15:10:07.208587       None            None      None  ...
# 4   2024-06-24 15:10:07.208587       None            None      None  ...
# 5   2024-06-24 15:10:07.208587       None            None      None  ...
# ..                         ...        ...             ...       ...  ...
# 739 2024-06-24 15:10:07.208587       None            None      None  ...
# 740 2024-06-24 15:10:07.208587       None            None      None  ...
# 741 2024-06-24 15:10:07.208587       None            None      None  ...
# 742 2024-06-24 15:10:07.208587       None            None      None  ...
# 743 2024-06-24 15:10:07.208587       None            None      None  ...
#
#     stepType                     name         level            step  \
# idx
# 1    instant  Pressure reduced to MSL  0.000000e+00 0 days 06:00:00
# 2    instant       Cloud mixing ratio  1.000000e+00 0 days 06:00:00
# 3    instant   Ice water mixing ratio  1.000000e+00 0 days 06:00:00
# 4    instant        Rain mixing ratio  1.000000e+00 0 days 06:00:00
# 5    instant        Snow mixing ratio  1.000000e+00 0 days 06:00:00
# ..       ...                      ...           ...             ...
# 739  instant      V component of wind  2.147486e+09 0 days 06:00:00
# 740  instant              Temperature  2.147486e+09 0 days 06:00:00
# 741  instant      Geopotential height  2.147486e+09 0 days 06:00:00
# 742  instant                 Pressure  2.147486e+09 0 days 06:00:00
# 743  instant     Vertical speed shear  2.147486e+09 0 days 06:00:00
#
#           time          valid_time  \
# idx
# 1   2023-09-28 2023-09-28 06:00:00
# 2   2023-09-28 2023-09-28 06:00:00
# 3   2023-09-28 2023-09-28 06:00:00
# 4   2023-09-28 2023-09-28 06:00:00
# 5   2023-09-28 2023-09-28 06:00:00
# ..         ...                 ...
# 739 2023-09-28 2023-09-28 06:00:00
# 740 2023-09-28 2023-09-28 06:00:00
# 741 2023-09-28 2023-09-28 06:00:00
# 742 2023-09-28 2023-09-28 06:00:00
# 743 2023-09-28 2023-09-28 06:00:00
#
#                                                    uri  offset_grib  \
# idx
# 1    /home/sparrow/Documents/sewaa_data/gfs_demo_da...          0.0
# 2    /home/sparrow/Documents/sewaa_data/gfs_demo_da...     984804.0
# 3    /home/sparrow/Documents/sewaa_data/gfs_demo_da...    1070431.0
# 4    /home/sparrow/Documents/sewaa_data/gfs_demo_da...    1314876.0
# 5    /home/sparrow/Documents/sewaa_data/gfs_demo_da...    1551504.0
# ..                                                 ...          ...
# 739  /home/sparrow/Documents/sewaa_data/gfs_demo_da...  535590536.0
# 740  /home/sparrow/Documents/sewaa_data/gfs_demo_da...  536236809.0
# 741  /home/sparrow/Documents/sewaa_data/gfs_demo_da...  536887172.0
# 742  /home/sparrow/Documents/sewaa_data/gfs_demo_da...  538061812.0
# 743  /home/sparrow/Documents/sewaa_data/gfs_demo_da...  539196945.0
#
#     length_grib inline_value
# idx
# 1      984804.0         None
# 2       85627.0         None
# 3      244445.0         None
# 4      236628.0         None
# 5       78043.0         None
# ..          ...          ...
# 739    646273.0         None
# 740    650363.0         None
# 741   1174640.0         None
# 742   1135133.0         None
# 743    499482.0         None
#
# [743 rows x 23 columns]

# %%
# %%time
mapped_index_list = []

deduped_mapping = mapping.loc[~mapping["attrs"].duplicated(keep="first"), :]
for date in pd.date_range("2023-09-01", "2023-09-30"):
  for runtime in range(0,24,6):
    horizon=6
    fname=f"gs://global-forecast-system/gfs.{date.strftime('%Y%m%d')}/{runtime:02}/atmos/gfs.t{runtime:02}z.pgrb2.0p25.f{horizon:03}"

    idxdf = dynamic_zarr_store.parse_grib_idx(
        fs=fsspec.filesystem("gcs"),
        basename=fname
    )

    mapped_index = dynamic_zarr_store.map_from_index(
        pd.Timestamp( date + datetime.timedelta(hours=runtime)),
        deduped_mapping,
        idxdf.loc[~idxdf["attrs"].duplicated(keep="first"), :],
    )
    mapped_index_list.append(mapped_index)

gfs_kind = pd.concat(mapped_index_list)
gfs_kind
# Out:
# CPU times: user 3.63 s, sys: 132 ms, total: 3.76 s
# Wall time: 3min
#     varname         typeOfLevel stepType                     name  \
# 0     prmsl             meanSea  instant  Pressure reduced to MSL
# 1     clwmr              hybrid  instant       Cloud mixing ratio
# 2      icmr              hybrid  instant   Ice water mixing ratio
# 3      rwmr              hybrid  instant        Rain mixing ratio
# 4      snmr              hybrid  instant        Snow mixing ratio
# ..      ...                 ...      ...                      ...
# 732       v  potentialVorticity  instant      V component of wind
# 733       t  potentialVorticity  instant              Temperature
# 734      gh  potentialVorticity  instant      Geopotential height
# 735    pres  potentialVorticity  instant                 Pressure
# 736    vwsh  potentialVorticity  instant     Vertical speed shear
#
#                step         level                time          valid_time  \
# 0   0 days 06:00:00  0.000000e+00 2023-09-01 00:00:00 2023-09-01 06:00:00
# 1   0 days 06:00:00  1.000000e+00 2023-09-01 00:00:00 2023-09-01 06:00:00
# 2   0 days 06:00:00  1.000000e+00 2023-09-01 00:00:00 2023-09-01 06:00:00
# 3   0 days 06:00:00  1.000000e+00 2023-09-01 00:00:00 2023-09-01 06:00:00
# 4   0 days 06:00:00  1.000000e+00 2023-09-01 00:00:00 2023-09-01 06:00:00
# ..              ...           ...                 ...                 ...
# 732 0 days 06:00:00  2.147486e+09 2023-09-30 18:00:00 2023-10-01 00:00:00
# 733 0 days 06:00:00  2.147486e+09 2023-09-30 18:00:00 2023-10-01 00:00:00
# 734 0 days 06:00:00  2.147486e+09 2023-09-30 18:00:00 2023-10-01 00:00:00
# 735 0 days 06:00:00  2.147486e+09 2023-09-30 18:00:00 2023-10-01 00:00:00
# 736 0 days 06:00:00  2.147486e+09 2023-09-30 18:00:00 2023-10-01 00:00:00
#
#                                                    uri     offset   length  \
# 0    gs://global-forecast-system/gfs.20230901/00/at...          0   877361
# 1    gs://global-forecast-system/gfs.20230901/00/at...     877361    90753
# 2    gs://global-forecast-system/gfs.20230901/00/at...     968114   228036
# 3    gs://global-forecast-system/gfs.20230901/00/at...    1196150   266763
# 4    gs://global-forecast-system/gfs.20230901/00/at...    1462913    81052
# ..                                                 ...        ...      ...
# 732  gs://global-forecast-system/gfs.20230930/18/at...  535413574   651311
# 733  gs://global-forecast-system/gfs.20230930/18/at...  536064885   651260
# 734  gs://global-forecast-system/gfs.20230930/18/at...  536716145  1175436
# 735  gs://global-forecast-system/gfs.20230930/18/at...  537891581  1135959
# 736  gs://global-forecast-system/gfs.20230930/18/at...  539027540   498795
#
#     inline_value grib_crc32         grib_updated_at idx_crc32  \
# 0           None   0f2Mww== 2023-09-01 03:36:52.570  ZmkdeQ==
# 1           None   0f2Mww== 2023-09-01 03:36:52.570  ZmkdeQ==
# 2           None   0f2Mww== 2023-09-01 03:36:52.570  ZmkdeQ==
# 3           None   0f2Mww== 2023-09-01 03:36:52.570  ZmkdeQ==
# 4           None   0f2Mww== 2023-09-01 03:36:52.570  ZmkdeQ==
# ..           ...        ...                     ...       ...
# 732         None   AxWcLQ== 2023-09-30 21:35:37.944  VIpnnw==
# 733         None   AxWcLQ== 2023-09-30 21:35:37.944  VIpnnw==
# 734         None   AxWcLQ== 2023-09-30 21:35:37.944  VIpnnw==
# 735         None   AxWcLQ== 2023-09-30 21:35:37.944  VIpnnw==
# 736         None   AxWcLQ== 2023-09-30 21:35:37.944  VIpnnw==
#
#              idx_updated_at                 indexed_at
# 0   2023-09-01 03:34:44.443 2024-06-24 15:16:33.560532
# 1   2023-09-01 03:34:44.443 2024-06-24 15:16:33.560532
# 2   2023-09-01 03:34:44.443 2024-06-24 15:16:33.560532
# 3   2023-09-01 03:34:44.443 2024-06-24 15:16:33.560532
# 4   2023-09-01 03:34:44.443 2024-06-24 15:16:33.560532
# ..                      ...                        ...
# 732 2023-09-30 21:34:36.675 2024-06-24 15:19:32.370296
# 733 2023-09-30 21:34:36.675 2024-06-24 15:19:32.370296
# 734 2023-09-30 21:34:36.675 2024-06-24 15:19:32.370296
# 735 2023-09-30 21:34:36.675 2024-06-24 15:19:32.370296
# 736 2023-09-30 21:34:36.675 2024-06-24 15:19:32.370296
#
# [88440 rows x 17 columns]

# %%
#gfs_kind

gfs_files = [
    "/home/sparrow/Documents/sewaa_data/gfs.t00z.pgrb2.0p25.f000",
    "/home/sparrow/Documents/sewaa_data/gfs.t00z.pgrb2.0p25.f003"
]

# This operation reads two of the large Grib2 files from GCS
# scan_grib extracts the zarr kerchunk metadata for each individual grib message
# grib_tree builds a zarr/xarray compatible hierarchical view of the dataset
gfs_grib_tree_store = grib_tree([group for f in gfs_files for group in scan_grib(f)])
deflated_gfs_grib_tree_store = copy.deepcopy(gfs_grib_tree_store)
#dynamic_zarr_store.strip_datavar_chunks(deflated_gfs_grib_tree_store)
# Out:
# Dropping unknown variable in msg# 578. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 586. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 665. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 1274. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 1275. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 1285. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# Dropping unknown variable in msg# 1407. Compare with the grib idx file to help identify it and build an ecCodes local grib definitions file to fix it.
# /home/sparrow/micromamba/envs/venv-20240425/lib/python3.12/site-packages/kerchunk/combine.py:370: UserWarning: Concatenated coordinate 'time' contains less than expectednumber of values across the datasets: [1693526400]
#   warnings.warn(
# /home/sparrow/micromamba/envs/venv-20240425/lib/python3.12/site-packages/kerchunk/combine.py:370: UserWarning: Concatenated coordinate 'step' contains less than expectednumber of values across the datasets: [3.]
#   warnings.warn(

# %%
#%%time
# It is fast to rebuild the datatree - but lets pull out two varables to look at...
gfs_store = dynamic_zarr_store.reinflate_grib_store(
    axes=axes,
    aggregation_type=dynamic_zarr_store.AggregationType.HORIZON,
    #chunk_index=gfs_kind.loc[~gfs_kind.varname.isin(["cape","cin","cpofp","gh","hlcy","mslet","soilw","st","vis"])],
    chunk_index=gfs_kind.loc[gfs_kind.varname.isin(["t2m"])],
    #chunk_index=gfs_kind,
    zarr_ref_store=deflated_gfs_grib_tree_store
)

# %%
with open(f'gfs-demo-zstore-dgc-method.pkl', 'wb') as pickle_file:
        pickle.dump(gfs_store, pickle_file)

# %% [markdown]
# ## loading the data

# %%
with open('gfs-demo-zstore-dgc-method.pkl', 'rb') as pickle_file:
    gfs_store = pickle.load(pickle_file)

# %%
gfs_dt = datatree.open_datatree(fsspec.filesystem("reference", fo=gfs_store).get_mapper(""), engine="zarr", consolidated=False)
gfs_dt
# Out:
# DataTree('None', parent=None)
# └── DataTree('t2m')
#     │   Dimensions:  ()
#     │   Data variables:
#     │       *empty*
#     │   Attributes:
#     │       name:     2 metre temperature
#     └── DataTree('instant')
#         │   Dimensions:  ()
#         │   Data variables:
#         │       *empty*
#         │   Attributes:
#         │       stepType:  instant
#         └── DataTree('heightAboveGround')
#                 Dimensions:            (latitude: 721, longitude: 1440, model_horizons: 1,
#                                         valid_times: 120)
#                 Coordinates:
#                     heightAboveGround  float64 8B ...
#                   * latitude           (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#                   * longitude          (longitude) float64 12kB 0.0 0.25 0.5 ... 359.5 359.8
#                     step               (model_horizons, valid_times) timedelta64[ns] 960B ...
#                     time               (model_horizons, valid_times) datetime64[ns] 960B ...
#                     valid_time         (model_horizons, valid_times) datetime64[ns] 960B ...
#                 Dimensions without coordinates: model_horizons, valid_times
#                 Data variables:
#                     t2m                (model_horizons, valid_times, latitude, longitude) float64 997MB ...
#                 Attributes:
#                     typeOfLevel:  heightAboveGround

# %%
with open('zstore-dgc-method-v1.pkl', 'rb') as pickle_file:
    gfs_store_v1 = pickle.load(pickle_file)

# %%
gfs_ds = xr.open_dataset(
    fsspec.filesystem("reference", fo=gfs_store_v1).get_mapper(""),
    engine="zarr",
    consolidated=False
)
gfs_ds
# Out:
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*

# %%
aa=gfs_dt["t2m/instant/heightAboveGround"].to_dataset()
#aa1=aa["instant/heightAboveGround"].to_dataset()
aa['time'] = aa.time.astype(str)
aa['valid_time'] = aa.valid_time.astype(str)
#aa['step'] = aa.step.astype(str)
aa1=aa.drop_vars('step')

# %%
aa1
# Out:
# <xarray.Dataset> Size: 997MB
# Dimensions:            (latitude: 721, longitude: 1440, model_horizons: 1,
#                         valid_times: 120)
# Coordinates:
#     heightAboveGround  float64 8B ...
#   * latitude           (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude          (longitude) float64 12kB 0.0 0.25 0.5 ... 359.5 359.8
#     time               (model_horizons, valid_times) <U48 23kB '2023-09-01T00...
#     valid_time         (model_horizons, valid_times) <U48 23kB '2023-09-01T06...
# Dimensions without coordinates: model_horizons, valid_times
# Data variables:
#     t2m                (model_horizons, valid_times, latitude, longitude) float64 997MB ...
# Attributes:
#     typeOfLevel:  heightAboveGround

# %%
import pandas as pd
for date in pd.date_range("2023-09-01", "2023-09-05"):
  for runtime in range(0,63,3):
    horizon=3
    fname=f"gs://global-forecast-system/gfs.{date.strftime('%Y%m%d')}/00/atmos/gfs.t00z.pgrb2.0p25.f{runtime:03}"
    print(fname)
# Out:
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f000
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f003
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f006
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f009
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f012
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f015
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f018
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f021
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f024
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f027
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f030
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f033
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f036
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f039
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f042
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f045
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f048
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f051
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f054
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f057
# gs://global-forecast-system/gfs.20230901/00/atmos/gfs.t00z.pgrb2.0p25.f060
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f000
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f003
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f006
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f009
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f012
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f015
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f018
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f021
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f024
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f027
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f030
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f033
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f036
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f039
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f042
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f045
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f048
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f051
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f054
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f057
# gs://global-forecast-system/gfs.20230902/00/atmos/gfs.t00z.pgrb2.0p25.f060
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f000
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f003
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f006
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f009
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f012
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f015
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f018
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f021
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f024
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f027
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f030
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f033
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f036
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f039
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f042
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f045
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f048
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f051
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f054
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f057
# gs://global-forecast-system/gfs.20230903/00/atmos/gfs.t00z.pgrb2.0p25.f060
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f000
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f003
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f006
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f009
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f012
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f015
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f018
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f021
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f024
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f027
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f030
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f033
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f036
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f039
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f042
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f045
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f048
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f051
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f054
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f057
# gs://global-forecast-system/gfs.20230904/00/atmos/gfs.t00z.pgrb2.0p25.f060
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f000
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f003
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f006
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f009
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f012
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f015
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f018
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f021
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f024
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f027
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f030
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f033
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f036
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f039
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f042
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f045
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f048
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f051
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f054
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f057
# gs://global-forecast-system/gfs.20230905/00/atmos/gfs.t00z.pgrb2.0p25.f060
